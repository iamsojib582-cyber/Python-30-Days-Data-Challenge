# %%
print("I Love You Sanzida")
# Out:
# I Love You Sanzida

# %%
print("Do you Love Me")
# Out:
# Do you Love Me

# %%
import pandas as pd
raw_data={ 
'Month':['Jan','Feb','Mar','Apr','May'],
'Sales':[2000,3000,4000,5000,6000],
'Expenses':[1500,2500,3500,4500,5500]
}
df=pd.DataFrame(raw_data)
df['Profit']=df['Sales']-df['Expenses']

# %%
# Out:
#   Month  Sales  Expenses  Profit
# 0   Jan   2000      1500     500
# 1   Feb   3000      2500     500
# 2   Mar   4000      3500     500
# 3   Apr   5000      4500     500
# 4   May   6000      5500     500
# Month with highest profit: Jan

# %%
print(df)
highest_profit_month=df.loc[df['Profit'].idxmax(),'Month']
print("Month with highest profit:",highest_profit_month)

# %%
marriage_details={
    'husband_name':'Sajeeb',
    'wife_name':'Sanzida'
}
print(marriage_details)
# Out:
# {'husband_name': 'Sajeeb', 'wife_name': 'Sanzida'}
